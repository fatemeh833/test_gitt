# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemeh833/test_gitt/blob/main/numpy_matplotlib_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## create a sinusoidal signal

# %%
x = np.linspace(-5, 5, 500)
y1 = x**3
y2 = np.cos(1.2*x)
y3 = np.exp(-(x**2))

# %% [markdown]
# ## plot the signal

# %%
plt.figure(figsize=(4, 3))
plt.plot(y1, 'g--')
plt.title('Plot of x**3')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# ##Plot multiple signals

# %%
plt.figure(figsize=(5, 3))
plt.plot(x, y2,'g--' ,label='cos 1.2*x')
plt.plot(x, y3,'r' ,label='exp(-x**2)')
plt.legend()
plt.show()
